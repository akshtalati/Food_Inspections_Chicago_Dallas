# %%
df1 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/talati.ak@northeastern.edu/Dallas_profiling.csv")

# %%
print("Schema:")
df1.printSchema()

print("Total Rows:", df1.count())
print("Total Columns:", len(df1.columns))

df1.show(5)
# Out:
# Schema:
# root
#  |-- Restaurant Name: string (nullable = true)
#  |-- Inspection Type: string (nullable = true)
#  |-- Inspection Date: string (nullable = true)
#  |-- Inspection Score: string (nullable = true)
#  |-- Street Number: string (nullable = true)
#  |-- Street Name: string (nullable = true)
#  |-- Street Direction: string (nullable = true)
#  |-- Street Type: string (nullable = true)
#  |-- Street Unit: string (nullable = true)
#  |-- Street Address: string (nullable = true)
#  |-- Zip Code: string (nullable = true)
#  |-- Violation Description - 1: string (nullable = true)
#  |-- Violation Points - 1: string (nullable = true)
#  |-- Violation Detail - 1: string (nullable = true)
#  |-- Violation Memo - 1: string (nullable = true)
#  |-- Violation Description - 2: string (nullable = true)
#  |-- Violation Points - 2: string (nullable = true)
#  |-- Violation Detail - 2: string (nullable = true)
#  |-- Violation Memo - 2: string (nullable = true)
#  |-- Violation Description - 3: string (nullable = true)
#  |-- Violation Points - 3: string (nullable = true)
#  |-- Violation Detail - 3: string (nullable = true)
#  |-- Violation Memo - 3: string (nullable = true)
#  |-- Violation Description - 4: string (nullable = true)
#  |-- Violation Points - 4: string (nullable = true)
#  |-- Violation Detail - 4: string (nullable = true)
#  |-- Violation Memo - 4: string (nullable = true)
#  |-- Violation Description - 5: string (nullable = true)
#  |-- Violation Points - 5: string (nullable = true)
#  |-- Violation Detail - 5: string (nullable = true)
#  |-- Violation Memo - 5: string (nullable = true)
#  |-- Violation Description - 6: string (nullable = true)
#  |-- Violation Points - 6: string (nullable = true)
#  |-- Violation Detail - 6: string (nullable = true)
#  |-- Violation Memo - 6: string (nullable = true)
#  |-- Violation Description - 7: string (nullable = true)
#  |-- Violation Points - 7: string (nullable = true)
#  |-- Violation Detail - 7: string (nullable = true)
#  |-- Violation Memo - 7: string (nullable = true)
#  |-- Violation Description - 8: string (nullable = true)
#  |-- Violation Points - 8: string (nullable = true)
#  |-- Violation Detail - 8: string (nullable = true)
#  |-- Violation Memo - 8: string (nullable = true)
#  |-- Violation Description - 9: string (nullable = true)
#  |-- Violation Points - 9: string (nullable = true)
#  |-- Violation Detail - 9: string (nullable = true)
#  |-- Violation Memo - 9: string (nullable = true)
#  |-- Violation Description - 10: string (nullable = true)
#  |-- Violation Points - 10: string (nullable = true)
#  |-- Violation Detail - 10: string (nullable = true)
#  |-- Violation Memo - 10: string (nullable = true)
#  |-- Violation Description - 11: string (nullable = true)
#  |-- Violation Points - 11: string (nullable = true)
#  |-- Violation Detail - 11: string (nullable = true)
#  |-- Violation Memo - 11: string (nullable = true)
#  |-- Violation Description - 12: string (nullable = true)
#  |-- Violation Points - 12: string (nullable = true)
#  |-- Violation Detail - 12: string (nullable = true)
#  |-- Violation Memo - 12: string (nullable = true)
#  |-- Violation Description - 13: string (nullable = true)
#  |-- Violation Points - 13: string (nullable = true)
#  |-- Violation Detail - 13: string (nullable = true)
#  |-- Violation Memo - 13: string (nullable = true)
#  |-- Violation Description - 14: string (nullable = true)
#  |-- Violation Points - 14: string (nullable = true)
#  |-- Violation Detail - 14: string (nullable = true)
#  |-- Violation Memo - 14: string (nullable = true)
#  |-- Violation Description - 15: string (nullable = true)
#  |-- Violation Points - 15: string (nullable = true)
#  |-- Violation Detail - 15: string (nullable = true)
#  |-- Violation Memo - 15: string (nullable = true)
#  |-- Violation Description - 16: string (nullable = true)
#  |-- Violation Points - 16: string (nullable = true)
#  |-- Violation Detail - 16: string (nullable = true)
#  |-- Violation Memo - 16: string (nullable = true)
#  |-- Violation Description - 17: string (nullable = true)
#  |-- Violation Points - 17: string (nullable = true)
#  |-- Violation Detail - 17: string (nullable = true)
#  |-- Violation Memo - 17: string (nullable = true)
#  |-- Violation Description - 18: string (nullable = true)
#  |-- Violation Points - 18: string (nullable = true)
#  |-- Violation Detail - 18: string (nullable = true)
#  |-- Violation Memo - 18: string (nullable = true)
#  |-- Violation Description - 19: string (nullable = true)
#  |-- Violation Points - 19: string (nullable = true)
#  |-- Violation Detail - 19: string (nullable = true)
#  |-- Violation Memo - 19: string (nullable = true)
#  |-- Violation Description - 20: string (nullable = true)
#  |-- Violation Points - 20: string (nullable = true)
#  |-- Violation Detail - 20: string (nullable = true)
#  |-- Violation  Memo - 20: string (nullable = true)
#  |-- Violation Description - 21: string (nullable = true)
#  |-- Violation Points - 21: string (nullable = true)
#  |-- Violation Detail - 21: string (nullable = true)
#  |-- Violation Memo - 21: string (nullable = true)
#  |-- Violation Description - 22: string (nullable = true)
#  |-- Violation Points - 22: string (nullable = true)
#  |-- Violation Detail - 22: string (nullable = true)
#  |-- Violation Memo - 22: string (nullable = true)
#  |-- Violation Description - 23: string (nullable = true)
#  |-- Violation Points - 23: string (nullable = true)
#  |-- Violation Detail - 23: string (nullable = true)
#  |-- Violation Memo - 23: string (nullable = true)
#  |-- Violation Description - 24: string (nullable = true)
#  |-- Violation Points - 24: string (nullable = true)
#  |-- Violation Detail - 24: string (nullable = true)
#  |-- Violation Memo - 24: string (nullable = true)
#  |-- Violation Description - 25: string (nullable = true)
#  |-- Violation Points - 25: string (nullable = true)
#  |-- Violation Detail - 25: string (nullable = true)
#  |-- Violation Memo - 25: string (nullable = true)
#  |-- Inspection Month: string (nullable = true)
#  |-- Inspection Year: string (nullable = true)
#  |-- Lat Long Location: string (nullable = true)
#
# Total Rows: 118212
# Total Columns: 114
# +--------------------+---------------+---------------+----------------+-------------+-----------+----------------+-----------+-----------+--------------+--------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+--------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+----------------+---------------+-----------------+
# |     Restaurant Name|Inspection Type|Inspection Date|Inspection Score|Street Number|Street Name|Street Direction|Street Type|Street Unit|Street Address|Zip Code|Violation Description - 1|Violation Points - 1|Violation Detail - 1|Violation Memo - 1|Violation Description - 2|Violation Points - 2|Violation Detail - 2|Violation Memo - 2|Violation Description - 3|Violation Points - 3|Violation Detail - 3|Violation Memo - 3|Violation Description - 4|Violation Points - 4|Violation Detail - 4|Violation Memo - 4|Violation Description - 5|Violation Points - 5|Violation Detail - 5|Violation Memo - 5|Violation Description - 6|Violation Points - 6|Violation Detail - 6|Violation Memo - 6|Violation Description - 7|Violation Points - 7|Violation Detail - 7|Violation Memo - 7|Violation Description - 8|Violation Points - 8|Violation Detail - 8|Violation Memo - 8|Violation Description - 9|Violation Points - 9|Violation Detail - 9|Violation Memo - 9|Violation Description - 10|Violation Points - 10|Violation Detail - 10|Violation Memo - 10|Violation Description - 11|Violation Points - 11|Violation Detail - 11|Violation Memo - 11|Violation Description - 12|Violation Points - 12|Violation Detail - 12|Violation Memo - 12|Violation Description - 13|Violation Points - 13|Violation Detail - 13|Violation Memo - 13|Violation Description - 14|Violation Points - 14|Violation Detail - 14|Violation Memo - 14|Violation Description - 15|Violation Points - 15|Violation Detail - 15|Violation Memo - 15|Violation Description - 16|Violation Points - 16|Violation Detail - 16|Violation Memo - 16|Violation Description - 17|Violation Points - 17|Violation Detail - 17|Violation Memo - 17|Violation Description - 18|Violation Points - 18|Violation Detail - 18|Violation Memo - 18|Violation Description - 19|Violation Points - 19|Violation Detail - 19|Violation Memo - 19|Violation Description - 20|Violation Points - 20|Violation Detail - 20|Violation  Memo - 20|Violation Description - 21|Violation Points - 21|Violation Detail - 21|Violation Memo - 21|Violation Description - 22|Violation Points - 22|Violation Detail - 22|Violation Memo - 22|Violation Description - 23|Violation Points - 23|Violation Detail - 23|Violation Memo - 23|Violation Description - 24|Violation Points - 24|Violation Detail - 24|Violation Memo - 24|Violation Description - 25|Violation Points - 25|Violation Detail - 25|Violation Memo - 25|Inspection Month|Inspection Year|Lat Long Location|
# +--------------------+---------------+---------------+----------------+-------------+-----------+----------------+-----------+-----------+--------------+--------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+--------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+----------------+---------------+-----------------+
# |                null|           null|           null|            null|         null|       null|            null|       null|       null|          null|    null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|                null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|            null|           null|             null|
# |(32.793368, -96.6...|           null|           null|            null|         null|       null|            null|       null|       null|          null|    null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|                null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|            null|           null|             null|
# |                null|           null|           null|            null|         null|       null|            null|       null|       null|          null|    null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|                null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|            null|           null|             null|
# |(32.869358, -96.7...|           null|           null|            null|         null|       null|            null|       null|       null|          null|    null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|                null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|            null|           null|             null|
# |                null|           null|           null|            null|         null|       null|            null|       null|       null|          null|    null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                     null|                null|                null|              null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|                null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|                      null|                 null|                 null|               null|            null|           null|             null|
# +--------------------+---------------+---------------+----------------+-------------+-----------+----------------+-----------+-----------+--------------+--------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+--------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+----------------+---------------+-----------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col, sum as _sum, when

print("Missing Value Count:")
null_counts = df1.select([
    _sum(when(col(c).isNull() | (col(c) == ""), 1).otherwise(0)).alias(c) for c in df1.columns
])
null_counts.show(truncate=False)
# Out:
# Missing Value Count:
# +---------------+---------------+---------------+----------------+-------------+-----------+----------------+-----------+-----------+--------------+--------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+--------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+----------------+---------------+-----------------+
# |Restaurant Name|Inspection Type|Inspection Date|Inspection Score|Street Number|Street Name|Street Direction|Street Type|Street Unit|Street Address|Zip Code|Violation Description - 1|Violation Points - 1|Violation Detail - 1|Violation Memo - 1|Violation Description - 2|Violation Points - 2|Violation Detail - 2|Violation Memo - 2|Violation Description - 3|Violation Points - 3|Violation Detail - 3|Violation Memo - 3|Violation Description - 4|Violation Points - 4|Violation Detail - 4|Violation Memo - 4|Violation Description - 5|Violation Points - 5|Violation Detail - 5|Violation Memo - 5|Violation Description - 6|Violation Points - 6|Violation Detail - 6|Violation Memo - 6|Violation Description - 7|Violation Points - 7|Violation Detail - 7|Violation Memo - 7|Violation Description - 8|Violation Points - 8|Violation Detail - 8|Violation Memo - 8|Violation Description - 9|Violation Points - 9|Violation Detail - 9|Violation Memo - 9|Violation Description - 10|Violation Points - 10|Violation Detail - 10|Violation Memo - 10|Violation Description - 11|Violation Points - 11|Violation Detail - 11|Violation Memo - 11|Violation Description - 12|Violation Points - 12|Violation Detail - 12|Violation Memo - 12|Violation Description - 13|Violation Points - 13|Violation Detail - 13|Violation Memo - 13|Violation Description - 14|Violation Points - 14|Violation Detail - 14|Violation Memo - 14|Violation Description - 15|Violation Points - 15|Violation Detail - 15|Violation Memo - 15|Violation Description - 16|Violation Points - 16|Violation Detail - 16|Violation Memo - 16|Violation Description - 17|Violation Points - 17|Violation Detail - 17|Violation Memo - 17|Violation Description - 18|Violation Points - 18|Violation Detail - 18|Violation Memo - 18|Violation Description - 19|Violation Points - 19|Violation Detail - 19|Violation Memo - 19|Violation Description - 20|Violation Points - 20|Violation Detail - 20|Violation  Memo - 20|Violation Description - 21|Violation Points - 21|Violation Detail - 21|Violation Memo - 21|Violation Description - 22|Violation Points - 22|Violation Detail - 22|Violation Memo - 22|Violation Description - 23|Violation Points - 23|Violation Detail - 23|Violation Memo - 23|Violation Description - 24|Violation Points - 24|Violation Detail - 24|Violation Memo - 24|Violation Description - 25|Violation Points - 25|Violation Detail - 25|Violation Memo - 25|Inspection Month|Inspection Year|Lat Long Location|
# +---------------+---------------+---------------+----------------+-------------+-----------+----------------+-----------+-----------+--------------+--------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+--------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+----------------+---------------+-----------------+
# |60             |51901          |51901          |51901           |51901        |51901      |95881           |53299      |94970      |51901         |51901   |58130                    |58130               |58701               |66971             |64726                    |64729               |65378               |73212             |72562                    |72565               |73182               |79969             |80266                    |80273               |80886               |86311             |87216                    |87216               |87750               |92051             |93134                    |93137               |93589               |96974             |98320                    |98323               |98749               |101242            |102777                   |102779              |103118              |105015            |106441                   |106447              |106704              |107974            |109504                    |109512               |109726               |110584             |112259                    |112262               |112409               |112962             |114551                    |114551               |114673               |114981             |116008                    |116006               |116076               |116262             |116730                    |116727               |116768               |116886             |117197                    |117194               |117225               |117320             |117571                    |117571               |117597               |117629             |117815                    |117818               |117824               |117852             |117982                    |117982               |117987               |118008             |118069                    |118069               |118071               |118085             |118121                    |118121               |118127               |118127              |118153                    |118153               |118160               |118156             |118180                    |118180               |118180               |118180             |118198                    |118198               |118198               |118198             |118204                    |118204               |118204               |118204             |118209                    |118209               |118209               |118209             |51952           |51913          |51913            |
# +---------------+---------------+---------------+----------------+-------------+-----------+----------------+-----------+-----------+--------------+--------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+-------------------------+--------------------+--------------------+------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+--------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+--------------------------+---------------------+---------------------+-------------------+----------------+---------------+-----------------+

# %%
print("Cardinality (Distinct values per column):")
for column in df1.columns:
    print(f"{column}: {df1.select(column).distinct().count()}")
# Out:
# Cardinality (Distinct values per column):
# Restaurant Name: 17904
# Inspection Type: 4
# Inspection Date: 989
# Inspection Score: 53
# Street Number: 3219
# Street Name: 789
# Street Direction: 5
# Street Type: 20
# Street Unit: 828
# Street Address: 6693
# Zip Code: 147
# Violation Description - 1: 461
# Violation Points - 1: 4
# Violation Detail - 1: 413
# Violation Memo - 1: 17915
# Violation Description - 2: 472
# Violation Points - 2: 9
# Violation Detail - 2: 419
# Violation Memo - 2: 15884
# Violation Description - 3: 473
# Violation Points - 3: 12
# Violation Detail - 3: 420
# Violation Memo - 3: 13497
# Violation Description - 4: 451
# Violation Points - 4: 13
# Violation Detail - 4: 402
# Violation Memo - 4: 11432
# Violation Description - 5: 415
# Violation Points - 5: 14
# Violation Detail - 5: 368
# Violation Memo - 5: 9492
# Violation Description - 6: 401
# Violation Points - 6: 11
# Violation Detail - 6: 355
# Violation Memo - 6: 7657
# Violation Description - 7: 383
# Violation Points - 7: 11
# Violation Detail - 7: 343
# Violation Memo - 7: 6167
# Violation Description - 8: 337
# Violation Points - 8: 11
# Violation Detail - 8: 297
# Violation Memo - 8: 4798
# Violation Description - 9: 312
# Violation Points - 9: 12
# Violation Detail - 9: 286
# Violation Memo - 9: 3741
# Violation Description - 10: 290
# Violation Points - 10: 8
# Violation Detail - 10: 263
# Violation Memo - 10: 2768
# Violation Description - 11: 253
# Violation Points - 11: 8
# Violation Detail - 11: 231
# Violation Memo - 11: 1923
# Violation Description - 12: 218
# Violation Points - 12: 7
# Violation Detail - 12: 201
# Violation Memo - 12: 1195
# Violation Description - 13: 177
# Violation Points - 13: 7
# Violation Detail - 13: 168
# Violation Memo - 13: 765
# Violation Description - 14: 165
# Violation Points - 14: 6
# Violation Detail - 14: 153
# Violation Memo - 14: 524
# Violation Description - 15: 133
# Violation Points - 15: 6
# Violation Detail - 15: 124
# Violation Memo - 15: 349
# Violation Description - 16: 111
# Violation Points - 16: 6
# Violation Detail - 16: 104
# Violation Memo - 16: 231
# Violation Description - 17: 92
# Violation Points - 17: 5
# Violation Detail - 17: 90
# Violation Memo - 17: 151
# Violation Description - 18: 61
# Violation Points - 18: 4
# Violation Detail - 18: 59
# Violation Memo - 18: 86
# Violation Description - 19: 42
# Violation Points - 19: 4
# Violation Detail - 19: 40
# Violation Memo - 19: 53
# Violation Description - 20: 27
# Violation Points - 20: 4
# Violation Detail - 20: 26
# Violation  Memo - 20: 37
# Violation Description - 21: 21
# Violation Points - 21: 4
# Violation Detail - 21: 20
# Violation Memo - 21: 25
# Violation Description - 22: 12
# Violation Points - 22: 4
# Violation Detail - 22: 12
# Violation Memo - 22: 14
# Violation Description - 23: 7
# Violation Points - 23: 4
# Violation Detail - 23: 7
# Violation Memo - 23: 7
# Violation Description - 24: 4
# Violation Points - 24: 2
# Violation Detail - 24: 4
# Violation Memo - 24: 4
# Violation Description - 25: 2
# Violation Points - 25: 2
# Violation Detail - 25: 2
# Violation Memo - 25: 2
# Inspection Month: 39
# Inspection Year: 16
# Lat Long Location: 6696

# %%
numeric_cols = [f.name for f in df1.schema.fields if str(f.dataType) in ['IntegerType', 'DoubleType', 'LongType', 'FloatType']]
if numeric_cols:
    df1.select(numeric_cols).describe().show()
else:
    print("No numeric columns found.")
# Out:
# No numeric columns found.

# %%
cat_cols = [f.name for f in df1.schema.fields if f.dataType.simpleString() == 'string']
print("Top Categories for Categorical Columns:")
for col_name in cat_cols:
    print(f"\n{col_name}:")
    df1.groupBy(col_name).count().orderBy("count", ascending=False).show(5, truncate=False)
# Out:
# Top Categories for Categorical Columns:
#
# Restaurant Name:
# +----------------------+-----+
# |Restaurant Name       |count|
# +----------------------+-----+
# |MCDONALDS             |474  |
# |BURGER KING           |259  |
# |WINGSTOP              |248  |
# |SONIC DRIVE IN        |243  |
# |CHIPOTLE MEXICAN GRILL|228  |
# +----------------------+-----+
# only showing top 5 rows
#
#
# Inspection Type:
# +---------------+-----+
# |Inspection Type|count|
# +---------------+-----+
# |Routine        |65765|
# |null           |51901|
# |Follow-up      |534  |
# |Complaint      |12   |
# +---------------+-----+
#
#
# Inspection Date:
# +---------------+-----+
# |Inspection Date|count|
# +---------------+-----+
# |null           |51901|
# |2022-10-27     |216  |
# |2022-11-10     |204  |
# |2022-12-21     |195  |
# |2024-01-12     |195  |
# +---------------+-----+
# only showing top 5 rows
#
#
# Inspection Score:
# +----------------+-----+
# |Inspection Score|count|
# +----------------+-----+
# |null            |51901|
# |100             |6221 |
# |95              |4600 |
# |97              |4559 |
# |94              |4135 |
# +----------------+-----+
# only showing top 5 rows
#
#
# Street Number:
# +-------------+-----+
# |Street Number|count|
# +-------------+-----+
# |null         |51901|
# |2500         |461  |
# |8008         |317  |
# |8687         |305  |
# |400          |290  |
# +-------------+-----+
# only showing top 5 rows
#
#
# Street Name:
# +-----------+-----+
# |Street Name|count|
# +-----------+-----+
# |null       |51901|
# |NORTHWEST  |2019 |
# |PRESTON    |1957 |
# |BUCKNER    |1564 |
# |GREENVILLE |1540 |
# +-----------+-----+
# only showing top 5 rows
#
#
# Street Direction:
# +----------------+-----+
# |Street Direction|count|
# +----------------+-----+
# |null            |95881|
# |W               |7025 |
# |N               |6196 |
# |S               |6039 |
# |E               |3071 |
# +----------------+-----+
#
#
# Street Type:
# +-----------+-----+
# |Street Type|count|
# +-----------+-----+
# |null       |53299|
# |RD         |16865|
# |AVE        |11318|
# |ST         |9557 |
# |LN         |7046 |
# +-----------+-----+
# only showing top 5 rows
#
#
# Street Unit:
# +-----------+-----+
# |Street Unit|count|
# +-----------+-----+
# |null       |94970|
# |#100       |2455 |
# |#110       |952  |
# |#A         |826  |
# |#101       |722  |
# +-----------+-----+
# only showing top 5 rows
#
#
# Street Address:
# +--------------------------+-----+
# |Street Address            |count|
# +--------------------------+-----+
# |null                      |51901|
# |3750 COTTON BOWL PLAZA    |177  |
# |11830 WEBB CHAPEL RD #1200|140  |
# |2201 N STEMMONS FRWY      |132  |
# |4849 W LAWTHER DR         |124  |
# +--------------------------+-----+
# only showing top 5 rows
#
#
# Zip Code:
# +--------+-----+
# |Zip Code|count|
# +--------+-----+
# |null    |51901|
# |75201   |3458 |
# |75220   |3039 |
# |75217   |2791 |
# |75211   |2739 |
# +--------+-----+
# only showing top 5 rows
#
#
# Violation Description - 1:
# +----------------------------------+-----+
# |Violation Description - 1         |count|
# +----------------------------------+-----+
# |null                              |58130|
# |*10 Clean Sight and Touch         |5370 |
# |*21 RFSM - Not On Site            |4645 |
# |*02 Cold Hold (41øF/45øF or below)|3522 |
# |*42 Dirty nonfood contact surfaces|2587 |
# +----------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Points - 1:
# +--------------------+-----+
# |Violation Points - 1|count|
# +--------------------+-----+
# |null                |58130|
# |3.0                 |25531|
# |1.0                 |18834|
# |2.0                 |15717|
# +--------------------+-----+
#
#
# Violation Detail - 1:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |Violation Detail - 1                                                                                                                                                                                                                                          |count|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |null                                                                                                                                                                                                                                                          |58701|
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          Equipment, food-contact surfaces, non-food contact surfaces and utensils.          (1) Equipment food-contact surfaces and utensils shall be clean to sight an|5370 |
# |Sec. 17-2.2(c)(1)(D)      (c) Registered food service managers. (1) Registered food service managers required.    (D) A food establishment shall have one registered food service manager employed and present in the establishment during all hours of operat|4645 |
# |228.75  Food.          Time and temperature control.          (f) Time/temperature controlled for safety food, hot and cold holding.     (1) Except during preparation, cooking, or cooling, or when time is used as the public health control as specified in|3522 |
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          (3) Nonfood-contact surfaces of equipment shall be kept free of an accumulation of dust, dirt, food residue, and other debris.                                |2587 |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Memo - 1:
# +------------------------------------+-----+
# |Violation Memo - 1                  |count|
# +------------------------------------+-----+
# |null                                |66971|
# |clean ice machine                   |102  |
# |Clean inside ice machine            |102  |
# |CLEAN INSIDE OF ICE MACHINE         |91   |
# |provide sign about inspection report|88   |
# +------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Description - 2:
# +----------------------------------+-----+
# |Violation Description - 2         |count|
# +----------------------------------+-----+
# |null                              |64726|
# |*21 RFSM - Not On Site            |3804 |
# |*10 Clean Sight and Touch         |3039 |
# |*42 Dirty nonfood contact surfaces|2973 |
# |*20 Grease Trap Tickets           |1745 |
# +----------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Points - 2:
# +-----------------------+-----+
# |Violation Points - 2   |count|
# +-----------------------+-----+
# |null                   |64729|
# |1.0                    |22137|
# |2.0                    |15891|
# |3.0                    |15440|
# |*20 Grease Trap Tickets|4    |
# +-----------------------+-----+
# only showing top 5 rows
#
#
# Violation Detail - 2:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |Violation Detail - 2                                                                                                                                                                                                                                          |count|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |null                                                                                                                                                                                                                                                          |65378|
# |Sec. 17-2.2(c)(1)(D)      (c) Registered food service managers. (1) Registered food service managers required.    (D) A food establishment shall have one registered food service manager employed and present in the establishment during all hours of operat|3804 |
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          Equipment, food-contact surfaces, non-food contact surfaces and utensils.          (1) Equipment food-contact surfaces and utensils shall be clean to sight an|3039 |
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          (3) Nonfood-contact surfaces of equipment shall be kept free of an accumulation of dust, dirt, food residue, and other debris.                                |2973 |
# |Ch.19-126.5(c))     A producer shall sign the manifest from the transporter when a load is picked up by the transporter and shall keep a copy of all trip tickets at the producer#s business office for three years.  The director may inspect these records a|1745 |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Memo - 2:
# +------------------------------------+-----+
# |Violation Memo - 2                  |count|
# +------------------------------------+-----+
# |null                                |73212|
# |No RFSM on site                     |103  |
# |CLEAN ALL                           |99   |
# |provide sign about inspection report|96   |
# |clean ice machine                   |79   |
# +------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Description - 3:
# +------------------------------------------------+-----+
# |Violation Description - 3                       |count|
# +------------------------------------------------+-----+
# |null                                            |72562|
# |*21 RFSM - Not On Site                          |2802 |
# |*42 Dirty nonfood contact surfaces              |2626 |
# |*10 Clean Sight and Touch                       |1582 |
# |*45  Premises shall be maintained in good repair|1574 |
# +------------------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Points - 3:
# +--------------------+-----+
# |Violation Points - 3|count|
# +--------------------+-----+
# |null                |72565|
# |1.0                 |21649|
# |2.0                 |14324|
# |3.0                 |9645 |
# |4.0                 |6    |
# +--------------------+-----+
# only showing top 5 rows
#
#
# Violation Detail - 3:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |Violation Detail - 3                                                                                                                                                                                                                                          |count|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |null                                                                                                                                                                                                                                                          |73182|
# |Sec. 17-2.2(c)(1)(D)      (c) Registered food service managers. (1) Registered food service managers required.    (D) A food establishment shall have one registered food service manager employed and present in the establishment during all hours of operat|2802 |
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          (3) Nonfood-contact surfaces of equipment shall be kept free of an accumulation of dust, dirt, food residue, and other debris.                                |2626 |
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          Equipment, food-contact surfaces, non-food contact surfaces and utensils.          (1) Equipment food-contact surfaces and utensils shall be clean to sight an|1582 |
# |228.186  Physical Facilities.          Premises, buildings, systems, rooms, fixtures, equipment, devices, and materials.          (a) Repairing.  The physical facilities shall be maintained in good repair.                                                 |1574 |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Memo - 3:
# +------------------------------------+-----+
# |Violation Memo - 3                  |count|
# +------------------------------------+-----+
# |null                                |79969|
# |provide sign about inspection report|98   |
# |provide hand washing sign           |83   |
# |CLEAN ALL                           |82   |
# |PROVIDE FOR ALL                     |80   |
# +------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Description - 4:
# +------------------------------------------------+-----+
# |Violation Description - 4                       |count|
# +------------------------------------------------+-----+
# |null                                            |80266|
# |*42 Dirty nonfood contact surfaces              |2275 |
# |*21 RFSM - Not On Site                          |1970 |
# |*45  Premises shall be maintained in good repair|1604 |
# |*42 Floors/walls/ceiling/nonfood dirty          |1254 |
# +------------------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Points - 4:
# +-------------------------+-----+
# |Violation Points - 4     |count|
# +-------------------------+-----+
# |null                     |80273|
# |1.0                      |19887|
# |2.0                      |11173|
# |3.0                      |6853 |
# |*10 Clean Sight and Touch|6    |
# +-------------------------+-----+
# only showing top 5 rows
#
#
# Violation Detail - 4:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |Violation Detail - 4                                                                                                                                                                                                                                          |count|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |null                                                                                                                                                                                                                                                          |80886|
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          (3) Nonfood-contact surfaces of equipment shall be kept free of an accumulation of dust, dirt, food residue, and other debris.                                |2275 |
# |Sec. 17-2.2(c)(1)(D)      (c) Registered food service managers. (1) Registered food service managers required.    (D) A food establishment shall have one registered food service manager employed and present in the establishment during all hours of operat|1970 |
# |228.186  Physical Facilities.          Premises, buildings, systems, rooms, fixtures, equipment, devices, and materials.          (a) Repairing.  The physical facilities shall be maintained in good repair.                                                 |1604 |
# |228.114  Equipment, Utensils, and Linens.          Frequency of cleaning.          (c) Nonfood-contact surfaces.  Nonfood-contact surfaces of equipment shall be cleaned at a frequency necessary to preclude accumulation of soil residues.                  |1254 |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Memo - 4:
# +------------------------------------+-----+
# |Violation Memo - 4                  |count|
# +------------------------------------+-----+
# |null                                |86311|
# |provide sign about inspection report|99   |
# |PROVIDE FOR ALL                     |82   |
# |wash hands before donning new gloves|76   |
# |CLEAN ALL                           |74   |
# +------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Description - 5:
# +------------------------------------------------+-----+
# |Violation Description - 5                       |count|
# +------------------------------------------------+-----+
# |null                                            |87216|
# |*42 Dirty nonfood contact surfaces              |1712 |
# |*45  Premises shall be maintained in good repair|1287 |
# |*21 RFSM - Not On Site                          |1263 |
# |*42 Floors/walls/ceiling/nonfood dirty          |1139 |
# +------------------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Points - 5:
# +----------------------+-----+
# |Violation Points - 5  |count|
# +----------------------+-----+
# |null                  |87216|
# |1.0                   |17289|
# |2.0                   |8373 |
# |3.0                   |5304 |
# |*21 RFSM - Not On Site|5    |
# +----------------------+-----+
# only showing top 5 rows
#
#
# Violation Detail - 5:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |Violation Detail - 5                                                                                                                                                                                                                                          |count|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |null                                                                                                                                                                                                                                                          |87750|
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          (3) Nonfood-contact surfaces of equipment shall be kept free of an accumulation of dust, dirt, food residue, and other debris.                                |1712 |
# |228.186  Physical Facilities.          Premises, buildings, systems, rooms, fixtures, equipment, devices, and materials.          (a) Repairing.  The physical facilities shall be maintained in good repair.                                                 |1287 |
# |Sec. 17-2.2(c)(1)(D)      (c) Registered food service managers. (1) Registered food service managers required.    (D) A food establishment shall have one registered food service manager employed and present in the establishment during all hours of operat|1263 |
# |228.114  Equipment, Utensils, and Linens.          Frequency of cleaning.          (c) Nonfood-contact surfaces.  Nonfood-contact surfaces of equipment shall be cleaned at a frequency necessary to preclude accumulation of soil residues.                  |1139 |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Memo - 5:
# +------------------------------------+-----+
# |Violation Memo - 5                  |count|
# +------------------------------------+-----+
# |null                                |92051|
# |provide sign about inspection report|85   |
# |CLEAN ALL                           |80   |
# |wash hands before donning new gloves|77   |
# |PROVIDE FOR ALL                     |71   |
# +------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Description - 6:
# +------------------------------------------------+-----+
# |Violation Description - 6                       |count|
# +------------------------------------------------+-----+
# |null                                            |93134|
# |*42 Dirty nonfood contact surfaces              |1343 |
# |*45  Premises shall be maintained in good repair|1040 |
# |*21 RFSM - Not On Site                          |964  |
# |*42 Floors/walls/ceiling/nonfood dirty          |893  |
# +------------------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Points - 6:
# +---------------------------------------------------------------------------------------------------+-----+
# |Violation Points - 6                                                                               |count|
# +---------------------------------------------------------------------------------------------------+-----+
# |null                                                                                               |93137|
# |1.0                                                                                                |14558|
# |2.0                                                                                                |6190 |
# |3.0                                                                                                |4305 |
# |*37 Food protected from cross contamination by storing the food in packages, covered containers, or|4    |
# +---------------------------------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#
# Violation Detail - 6:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |Violation Detail - 6                                                                                                                                                                                                                                          |count|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |null                                                                                                                                                                                                                                                          |93589|
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          (3) Nonfood-contact surfaces of equipment shall be kept free of an accumulation of dust, dirt, food residue, and other debris.                                |1343 |
# |228.186  Physical Facilities.          Premises, buildings, systems, rooms, fixtures, equipment, devices, and materials.          (a) Repairing.  The physical facilities shall be maintained in good repair.                                                 |1040 |
# |Sec. 17-2.2(c)(1)(D)      (c) Registered food service managers. (1) Registered food service managers required.    (D) A food establishment shall have one registered food service manager employed and present in the establishment during all hours of operat|964  |
# |228.114  Equipment, Utensils, and Linens.          Frequency of cleaning.          (c) Nonfood-contact surfaces.  Nonfood-contact surfaces of equipment shall be cleaned at a frequency necessary to preclude accumulation of soil residues.                  |893  |
# +--------
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# tion - 20                      |count |
# +------------------------------------------------+------+
# |null                                            |118121|
# |*47 Handwashing signage                         |8     |
# |*42 Floors/walls/ceiling/nonfood dirty          |7     |
# |*45  Premises shall be maintained in good repair|6     |
# |*47 Other Violations                            |6     |
# +------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Points - 20:
# +---------------------+------+
# |Violation Points - 20|count |
# +---------------------+------+
# |null                 |118121|
# |1.0                  |67    |
# |3.0                  |15    |
# |2.0                  |9     |
# +---------------------+------+
#
#
# Violation Detail - 20:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |Violation Detail - 20                                                                                                                                                                                                                                         |count |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |null                                                                                                                                                                                                                                                          |118127|
# |228.175  Physical Facilities.          Handwashing Sinks.          (e) Handwashing signage. A sign or poster that notifies food employees to wash their hands shall be provided at all handwashing sinks used by food employees and shall be clearly visible t|8     |
# |228.114  Equipment, Utensils, and Linens.          Frequency of cleaning.          (c) Nonfood-contact surfaces.  Nonfood-contact surfaces of equipment shall be cleaned at a frequency necessary to preclude accumulation of soil residues.                  |7     |
# |228.186  Physical Facilities.          Premises, buildings, systems, rooms, fixtures, equipment, devices, and materials.          (a) Repairing.  The physical facilities shall be maintained in good repair.                                                 |6     |
# |228.173  Physical Facilities.          Floors, walls, and ceilings.         (h) Walls and ceilings, studs, joists, and rafters. Except for temporary food establishments, studs, joists, and rafters may not be exposed in areas subject to moisture.         |5     |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation  Memo - 20:
# +-------------------------------------------------------------------------------+------+
# |Violation  Memo - 20                                                           |count |
# +-------------------------------------------------------------------------------+------+
# |null                                                                           |118127|
# |Clean inside of ice machine and inside of RIC on gaskets                       |3     |
# |Post last health inspection report or sign saying it is available upon request.|3     |
# |Soiled kitchen ceiling                                                         |3     |
# |No hand washing sign at hand sinks.                                            |3     |
# +-------------------------------------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Description - 21:
# +-------------------------------------------------+------+
# |Violation Description - 21                       |count |
# +-------------------------------------------------+------+
# |null                                             |118153|
# |*47 Other Violations                             |7     |
# |*20 Grease Trap Tickets                          |5     |
# |*45  Premises shall be maintained in good repair |5     |
# |*31 Handwashing lavatory - used for other purpose|4     |
# +-------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Points - 21:
# +---------------------+------+
# |Violation Points - 21|count |
# +---------------------+------+
# |null                 |118153|
# |1.0                  |29    |
# |3.0                  |18    |
# |2.0                  |12    |
# +---------------------+------+
#
#
# Violation Detail - 21:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |Violation Detail - 21                                                                                                                                                                                                                                         |count |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |null                                                                                                                                                                                                                                                          |118160|
# |228.186  Physical Facilities.          Premises, buildings, systems, rooms, fixtures, equipment, devices, and materials.          (a) Repairing.  The physical facilities shall be maintained in good repair.                                                 |5     |
# |Ch.19-126.5(c))     A producer shall sign the manifest from the transporter when a load is picked up by the transporter and shall keep a copy of all trip tickets at the producer#s business office for three years.  The director may inspect these records a|5     |
# |228.149  Water, Plumbing, and Waste.          Plumbing, operation and maintenance.          (a) Using a handwashing facility.          (2) A handwashing facility may not be used for purposes other than handwashing.                                        |4     |
# |õ228.33. Certified Food Protection Manager and Food Handler Requirements  (d) Except in a temporary food establishment and the certified food manager, all food employees shall successfully complete an accredited food handler training course, within 60 d |3     |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Memo - 21:
# +---------------------------------------------------------------------------+------+
# |Violation Memo - 21                                                        |count |
# +---------------------------------------------------------------------------+------+
# |null                                                                       |118156|
# |No one has a food manager certification on site.                           |3     |
# |Food handlers certificates must be provided for all food handling employees|3     |
# |grease trap paper work not onsite                                          |3     |
# |Soiled kitchen air vents                                                   |3     |
# +---------------------------------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Description - 22:
# +----------------------------------------------------------------------------------------------------+------+
# |Violation Description - 22                                                                          |count |
# +----------------------------------------------------------------------------------------------------+------+
# |null                                                                                                |118180|
# |*45  Premises shall be maintained in good repair                                                    |5     |
# |*47 Conditions of Permit-in use of food equipment                                                   |5     |
# |*25 Controlling pests. The presence of insects, rodents, and other pests shall be controlled to elim|3     |
# |*31 Handwashing lavatory - used for other purpose                                                   |3     |
# +----------------------------------------------------------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Points - 22:
# +---------------------+------+
# |Violation Points - 22|count |
# +---------------------+------+
# |null                 |118180|
# |1.0                  |16    |
# |2.0                  |14    |
# |3.0                  |2     |
# +---------------------+------+
#
#
# Violation Detail - 22:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |Violation Detail - 22                                                                                                                                                                                                                                         |count |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |null                                                                                                                                                                                                                                                          |118180|
# |228.186  Physical Facilities.          Premises, buildings, systems, rooms, fixtures, equipment, devices, and materials.          (a) Repairing.  The physical facilities shall be maintained in good repair.                                                 |5     |
# |228.248 Compliance           Conditions of retention, responsibilities of the permit holder.                          Upon acceptance of the permit issued by the regulatory authority, the permit holder in order to retain the permit shall:          (11) N|5     |
# |228.186  Physical Facilities.          Premises, buildings, systems, rooms, fixtures, equipment, devices, and materials.          (k) Controlling pests.  The presence of insects, rodents, and other pests shall be controlled to eliminate their presence on|3     |
# |228.149  Water, Plumbing, and Waste.          Plumbing, operation and maintenance.          (a) Using a handwashing facility.          (2) A handwashing facility may not be used for purposes other than handwashing.                                        |3     |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Memo - 22:
# +-------------------------------------------------------------------------------------------------------------+------+
# |Violation Memo - 22                                                                                          |count |
# +-------------------------------------------------------------------------------------------------------------+------+
# |null                                                                                                         |118180|
# |provide manufacture name for salsa                                                                           |3     |
# |Do not store items in hand sink, waste lines running through hand sink, washing utensils in hand washing sink|3     |
# |Multiple damaged kitchen ceiling tiles                                                                       |3     |
# |pest control paper not onsite                                                                                |3     |
# +-------------------------------------------------------------------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Description - 23:
# +-------------------------------------------------+------+
# |Violation Description - 23                       |count |
# +-------------------------------------------------+------+
# |null                                             |118198|
# |*19 Water &  Plumbing in good repair- per code   |3     |
# |*28 Date marking > 24 hrs,on site,temp 41F       |3     |
# |*22 Accredited food handler certificate - 60 days|2     |
# |*47 OTHER VIOLATIONS                             |2     |
# +-------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Points - 23:
# +---------------------+------+
# |Violation Points - 23|count |
# +---------------------+------+
# |null                 |118198|
# |2.0                  |5     |
# |3.0                  |5     |
# |1.0                  |4     |
# +---------------------+------+
#
#
# Violation Detail - 23:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |Violation Detail - 23                                                                                                                                                                                                                                         |count |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |null                                                                                                                                                                                                                                                          |118198|
# |228.149  Water, Plumbing, and Waste.          Plumbing, operation and maintenance.          (e) System maintained in good repair.  A plumbing system shall be:          (1) repaired according to the Plumbing Code;  and                                     |3     |
# |228.75  Food.          Time and temperature control.          (g) Ready-to-eat, TCS food, date marking.  (2) Except as specified in paragraphs (5) - (7) of this subsection, refrigerated, ready-to-eat, time/temperature controlled for safety food prepared |3     |
# |228.114  Equipment, Utensils, and Linens.          Frequency of cleaning.          (a) Equipment food-contact surfaces and utensils.          (1) Equipment food-contact surfaces and utensils shall be cleaned:          (E) at any time during the operation|2     |
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          Equipment, food-contact surfaces, non-food contact surfaces and utensils.          (2) The food-contact surfaces of cooking equipment and pans shall be kept f|2     |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Memo - 23:
# +-------------------------------------------------------------------------------------------------------+------+
# |Violation Memo - 23                                                                                    |count |
# +-------------------------------------------------------------------------------------------------------+------+
# |null                                                                                                   |118198|
# |fix handsink in women's bathroom                                                                       |3     |
# |clearly date mark TCS food for 7 days only                                                             |3     |
# |cooking equipment dirty with soils and grease accumulations  must be clean to avoid cross contamination|2     |
# |sanitize food surfaces during operational hours                                                        |2     |
# +-------------------------------------------------------------------------------------------------------+------+
# only showing top 5 rows
#
#
# Violation Description - 24:
# +-----------------------------------------------------------+------+
# |Violation Description - 24                                 |count |
# +-----------------------------------------------------------+------+
# |null                                                       |118204|
# |*36 Cloths in-use for wiping between uses stored           |3     |
# |*45 Drying Mops-air dry                                    |3     |
# |*46 Water, Plumbing, and Waste Plumbing Systems-good repair|2     |
# +-----------------------------------------------------------+------+
#
#
# Violation Points - 24:
# +---------------------+------+
# |Violation Points - 24|count |
# +---------------------+------+
# |null                 |118204|
# |1.0                  |8     |
# +---------------------+------+
#
#
# Violation Detail - 24:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |Violation Detail - 24                                                                                                                                                                                                                                         |count |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |null                                                                                                                                                                                                                                                          |118204|
# |228.68  Food.          Preventing Contamination From Equipment, Utensils, and Linens.         (d) Wiping cloths, use limitation.          (2) cloths in-use for wiping counters and other equipment surfaces shall be:         (A) held between uses in a chem|3     |
# |228.186  Physical Facilities.          Premises, buildings, systems, rooms, fixtures, equipment, devices, and materials.          (f) Drying mops.  After use, mops shall be placed in a position that allows them to air-dry without soiling walls, equipment|3     |
# |228.149  Water, Plumbing, and Waste.          Plumbing, operation and maintenance.          (e) System maintained in good repair.  A plumbing system shall be:          (2) maintained in good repair.                                                        |2     |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
#
#
# Violation Memo - 24:
# +-------------------------------------------------------------------------------------------+------+
# |Violation Memo - 24                                                                        |count |
# +-------------------------------------------------------------------------------------------+------+
# |null                                                                                       |118204|
# |Store wet wiping cloth in sanitizer solution                                               |3     |
# |mops need dry                                                                              |3     |
# |water faucets detach from sinks in all areas  must be replace or repair to proper condition|2     |
# +-------------------------------------------------------------------------------------------+------+
#
#
# Violation Description - 25:
# +----------------------------------+------+
# |Violation Description - 25        |count |
# +----------------------------------+------+
# |null                              |118209|
# |*42 Dirty nonfood contact surfaces|3     |
# +----------------------------------+------+
#
#
# Violation Points - 25:
# +---------------------+------+
# |Violation Points - 25|count |
# +---------------------+------+
# |null                 |118209|
# |1.0                  |3     |
# +---------------------+------+
#
#
# Violation Detail - 25:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |Violation Detail - 25                                                                                                                                                                                                         |count |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |null                                                                                                                                                                                                                          |118209|
# |228.113  Equipment, Utensils, and Linens.          Cleaning of equipment and utensils.          (3) Nonfood-contact surfaces of equipment shall be kept free of an accumulation of dust, dirt, food residue, and other debris.|3     |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
#
#
# Violation Memo - 25:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |Violation Memo - 25                                                                                                                                                        |count |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |null                                                                                                                                                                       |118209|
# |Dirty dust on fans and vents above food prep areas and counters. dirty food containers, outside RIC doors, stoves, ovens, walls, vents, vent filters. Ice on freezer floor.|3     |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
#
#
# Inspection Month:
# +----------------+-----+
# |Inspection Month|count|
# +----------------+-----+
# |null            |51952|
# |Mar 2022        |3051 |
# |Jan 2024        |2914 |
# |Dec 2022        |2679 |
# |Nov 2022        |2418 |
# +----------------+-----+
# only showing top 5 rows
#
#
# Inspection Year:
# +---------------+-----+
# |Inspection Year|count|
# +---------------+-----+
# |null           |51913|
# |FY2022         |22367|
# |FY2023         |21752|
# |FY2021         |13920|
# |FY2024         |8221 |
# +---------------+-----+
# only showing top 5 rows
#
#
# Lat Long Location:
# +--------------------------+-----+
# |Lat Long Location         |count|
# +--------------------------+-----+
# |null                      |51913|
# |3750 COTTON BOWL PLAZA    |177  |
# |11830 WEBB CHAPEL RD #1200|140  |
# |2201 N STEMMONS FRWY      |132  |
# |4849 W LAWTHER DR         |124  |
# +--------------------------+-----+
# only showing top 5 rows

# %%
total_rows = df1.count()
duplicate_rows = df1.groupBy(df1.columns).count().filter("count > 1").agg({"count": "sum"}).collect()[0][0]
duplicate_rows = duplicate_rows if duplicate_rows else 0
unique_rows = total_rows - duplicate_rows

print(f"Total Rows: {total_rows}")
print(f"Duplicate Rows: {duplicate_rows}")
print(f"Unique Rows: {unique_rows}")
# Out:
# Total Rows: 118212
# Duplicate Rows: 118195
# Unique Rows: 17
